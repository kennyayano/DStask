# %%
from community import community_louvain
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
df1 = pd.read_csv('C:/Users/flakk/OneDrive/Desktop/hubby/ds_cluster.csv', encoding= 'unicode_escape')
F = nx.from_pandas_edgelist(df1, source = 'Location2', target = 'EventCode', edge_attr = True,)
partition = community_louvain.best_partition(F)
size = float(len(set(partition.values())))
pos = nx.spring_layout(F)
nx.draw_networkx(F,node_color=list(partition.values()))
plt.savefig("C:/Users/flakk/OneDrive/Desktop/hubby/MyFigure.jpg")
